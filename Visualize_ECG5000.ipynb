# %% [markdown]
# <a href="https://colab.research.google.com/github/nina-prog/DataAnalysis_VAE/blob/main/Visualize_ECG5000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()

# %%
# Read data
df = pd.read_fwf('ecg5000_TRAIN.txt')
df.to_csv('ecg5000.csv')
# Flatten data to one dimensional array
time_series = df.to_numpy().flatten()
# Transform to list
y = list(time_series)

print(type(y))
print(len(y))
# Out:
# <class 'list'>
# 70359

# %%
x = np.arange(0, len(y), 1)

# set figure size
plt.figure(figsize=(25,6))
# Time series plot with Seaborn lineplot()
plt.plot(x, y, linewidth = 0.1, color="blue")
